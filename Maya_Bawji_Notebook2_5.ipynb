# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.5: Practice with Parquet and File Types*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%202/Notebook2.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
class Timer:
    def __enter__(self):
        self.start = time.perf_counter()
        return self

    def __exit__(self, *args):
        self.end = time.perf_counter()
        self.interval = self.end - self.start

# %% [markdown]
# ##### Read the Parqeut file and time it

# %%
with Timer() as t_pd:
    df = pd.read_parquet('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.parquet')
print(t_pd.interval)
# Out:
# 0.44763726900009715

# %% [markdown]
# #### Read the CSV file and time it

# %%
with Timer() as t_pd:
    df = pd.read_csv('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.csv')
print(t_pd.interval)
# Out:
# 0.2668831160001446

# %% [markdown]
# #### Read the ZIP file and time it

# %%
import zipfile
with Timer() as t_pd:
    df = pd.read_csv('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.zip', compression="zip")
print(t_pd.interval)
# Out:
# 0.18007059699993988

# %%
df_large = pd.concat([df, df, df, df, df])

# %%
df_large.shape
# Out:
# (8415, 5)

# %%
df_large.to_csv('large_data.csv', index=False)

# %%
df_large.to_parquet('large_data.parquet')

# %%
df_large.to_csv('large_data.zip', compression="zip", index=False)

# %%
with Timer() as t_pd:
    df = pd.read_parquet('large_data.parquet')
print(t_pd.interval)
# Out:
# 0.00733990900016579

# %%
with Timer() as t_pd:
    df = pd.read_csv('large_data.csv')
print(t_pd.interval)
# Out:
# 0.008943412000007811

# %%
with Timer() as t_pd:
    df = pd.read_csv('large_data.zip', compression="zip")
print(t_pd.interval)
# Out:
# 0.01003113199976724

# %%
df_larger = pd.concat([df_large, df_large])

# %%
df_larger.shape
# Out:
# (16830, 5)

# %%
df_larger.to_csv('larger_data.csv', index=False)

# %%
df_larger.to_parquet('larger_data.parquet')

# %%
df_larger.to_csv('larger_data.zip', compression="zip", index=False)

# %%
with Timer() as t_pd:
    df = pd.read_parquet('larger_data.parquet')
print(t_pd.interval)
# Out:
# 0.009266009000384656

# %%
with Timer() as t_pd:
    df = pd.read_csv('larger_data.csv')
print(t_pd.interval)
# Out:
# 0.01883597899995948

# %%
with Timer() as t_pd:
    df = pd.read_csv('larger_data.zip', compression="zip")
print(t_pd.interval)
# Out:
# 0.01319340200006991
