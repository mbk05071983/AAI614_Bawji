# %% [markdown]
# # AAI614 Collaboration Notebook
#
# **Open in Google Colab:** [Click here to open this notebook in Colab](https://colab.research.google.com/drive/1oA2SVuTwtMLDm82-gWMvY8bSXo6Hd505?authuser=1&hl=fr)

# %%
name = "Maya"
course = "AAI614"

print("Student:", name)
print("Course:", course)
print("Welcome to my Python notebook!")
# Out:
# Student: Maya
# Course: AAI614
# Welcome to my Python notebook!
